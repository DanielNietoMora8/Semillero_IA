# %% [markdown]
# # Funcion para metodo1:frecuencia de corte con optcutfreq

# %%
import numpy as np
import librosa
from optcutfreq import optcutfreq
import os
import random
import pandas as pd

def calcular_frecuencia_corte_ideal(carpeta, num_audios, frecuencia_muestreo=44100):
    # Obtener el nombre de la carpeta
    nombre_carpeta = os.path.basename(carpeta)
    
    # Listar los archivos de audio en la carpeta
    archivos = [archivo for archivo in os.listdir(carpeta) if archivo.lower().endswith('.wav')]

    # Verificar si hay suficientes archivos de audio en la carpeta
    if len(archivos) < num_audios:
        print("No hay suficientes archivos de audio en la carpeta.")
        return

    # Seleccionar aleatoriamente 'num_audios' archivos de audio
    archivos_a_procesar = random.sample(archivos, num_audios)

    # Crear un DataFrame vacío para almacenar los resultados
    resultados_df = pd.DataFrame(columns=['Nombre del Audio', 'Frecuencia de Corte Óptima'])

    for archivo in archivos_a_procesar:
        # Construir la ruta completa del archivo de audio
        ruta_audio = os.path.join(carpeta, archivo)

        # Cargar el archivo de audio
        audio, sr = librosa.load(ruta_audio, sr=frecuencia_muestreo)

        # Obtener la frecuencia de corte óptima
        fc_opt = optcutfreq(audio, freq=sr, show=True)

        # Agregar los resultados al DataFrame
        resultados_df = resultados_df.append({'Nombre del Audio': archivo, 'Frecuencia de Corte Óptima': fc_opt}, ignore_index=True)

        # Imprimir la frecuencia de corte óptima para cada archivo
        print(f"Frecuencia de corte óptima para {archivo}: {fc_opt}")

    # Guardar el DataFrame en un archivo CSV con el nombre de la carpeta
    nombre_archivo_csv = f'{nombre_carpeta}_cut_off.csv'
    resultados_df.to_csv(nombre_archivo_csv, index=False)

# Ejemplo de uso
carpeta_audios = 'E:/pythin_videos/Ecoacustica/Jaguas_2018/G58_m/G58_m'
num_audios_a_analizar = 20
frecuencia_muestreo = 44100

calcular_frecuencia_corte_ideal(carpeta_audios, num_audios_a_analizar, frecuencia_muestreo)
# Out:
# <ipython-input-37-dfc02e0d6832>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultados_df = resultados_df.append({'Nombre del Audio': archivo, 'Frecuencia de Corte Óptima': fc_opt}, ignore_index=True)
# Frecuencia de corte óptima para G58_20180704_001600.wav: 5543.616053500727
# <ipython-input-37-dfc02e0d6832>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resultados_df = resultados_df.append({'Nombre del Audio': archivo, 'Frecuencia de Corte Óptima': fc_opt}, ignore_index=True)
# Frecuencia de corte óptima para G58_20180703_193000.wav: 5641.7730045116705
# <ipython-input-37-dfc02e0d6832>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# # Crear df para la media por cada grabadora

# %%
import pandas as pd
import os

# DataFrame global para acumular los resultados
resultados_df = pd.DataFrame()

def procesar_archivo(ruta_archivo):
    global resultados_df
    
    # Obtén el nombre del archivo CSV (sin la extensión) para usarlo como nombre de columna
    nombre_archivo = os.path.splitext(os.path.basename(ruta_archivo))[0]

    # Lee el archivo CSV
    df = pd.read_csv(ruta_archivo)

    # Calcula el promedio de la columna "Frecuencia de Corte Óptima"
    promedio = df["Frecuencia de Corte Óptima"].mean()

    # Agrega una columna al DataFrame global con el nombre del archivo y el promedio
    resultados_df[nombre_archivo] = [promedio * 2]

# Ejemplo de uso

archivos = [
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G03_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G06_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G07_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G08_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G09_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G13_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G34_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G15_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G17_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G19_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G23_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G24_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G25_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G27_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G28_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G29_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G34_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G35_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G36_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G37_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G40_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G41_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G46_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G47_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G49_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G50_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G51_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G52_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G54_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G57_m_cut_off.csv",
    "E:/pythin_videos/Ecoacustica/Semillero_IA/Andres_Alzate/frecuencia_corte_metodo1/G58_m_cut_off.csv"
]


for archivo in archivos:
    procesar_archivo(archivo)

# Guarda el DataFrame global en un archivo CSV
resultados_df.to_csv("frecuencia_media.csv", index=False)

# %%
resultados_df
# Out:
#    G03_m_cut_off  G06_m_cut_off  G07_m_cut_off  G08_m_cut_off  G09_m_cut_off  \
# 0   11522.925236   10866.344266   11550.849291    11241.32212   11671.502933
#
#    G13_m_cut_off  G34_m_cut_off  G15_m_cut_off  G17_m_cut_off  G19_m_cut_off  \
# 0   10634.375643   11206.424028     11770.0009   11169.817764   11494.705063
#
#    ...  G41_m_cut_off  G46_m_cut_off  G47_m_cut_off  G49_m_cut_off  \
# 0  ...   10969.673546   11551.050763   11380.911317   11187.649026
#
#    G50_m_cut_off  G51_m_cut_off  G52_m_cut_off  G54_m_cut_off  G57_m_cut_off  \
# 0   11450.464737   11809.895711   11606.332371   11501.604789   11864.147768
#
#    G58_m_cut_off
# 0   11113.375343
#
# [1 rows x 30 columns]
